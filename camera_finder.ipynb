# %%
#!pip install torch
#!pip install Pillow
#!pip install ipyvolume
# Out:
# Collecting ipyvolume
#   Downloading ipyvolume-0.5.2-py2.py3-none-any.whl (2.9 MB)
# Requirement already satisfied: traitlets in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipyvolume) (4.3.3)
# Collecting ipywebrtc
#   Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
# Requirement already satisfied: Pillow in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipyvolume) (7.0.0)
# Collecting pythreejs>=1.0.0
#   Downloading pythreejs-2.3.0-py2.py3-none-any.whl (3.4 MB)
# Requirement already satisfied: requests in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipyvolume) (2.23.0)
# Collecting traittypes
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipyvolume) (1.18.3)
# Requirement already satisfied: ipywidgets>=7.5 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipyvolume) (7.5.1)
# Requirement already satisfied: six in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from traitlets->ipyvolume) (1.14.0)
# Requirement already satisfied: decorator in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from traitlets->ipyvolume) (4.4.2)
# Requirement already satisfied: ipython-genutils in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from traitlets->ipyvolume) (0.2.0)
# Collecting ipydatawidgets>=1.1.1
#   Downloading ipydatawidgets-4.2.0-py2.py3-none-any.whl (275 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from requests->ipyvolume) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from requests->ipyvolume) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from requests->ipyvolume) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from requests->ipyvolume) (1.25.9)
# Requirement already satisfied: nbformat>=4.2.0 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipywidgets>=7.5->ipyvolume) (5.0.6)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipywidgets>=7.5->ipyvolume) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipywidgets>=7.5->ipyvolume) (5.3.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipywidgets>=7.5->ipyvolume) (7.14.0)
# Requirement already satisfied: jupyter-core in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5->ipyvolume) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5->ipyvolume) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (6.0.3)
# Requirement already satisfied: jupyter-client in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->ipyvolume) (6.1.3)
# Requirement already satisfied: tornado>=4.2 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->ipyvolume) (6.0.4)
# Requirement already satisfied: colorama; sys_platform == "win32" in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (0.4.3)
# Requirement already satisfied: jedi>=0.10 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (0.17.0)
# Requirement already satisfied: pygments in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (46.1.3.post20200330)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (3.0.5)
# Requirement already satisfied: backcall in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (0.1.0)
# Requirement already satisfied: pickleshare in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (0.7.5)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5->ipyvolume) (227)
# Requirement already satisfied: pyrsistent>=0.14.0 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->ipyvolume) (0.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->ipyvolume) (1.6.0)
# Requirement already satisfied: attrs>=17.4.0 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->ipyvolume) (19.3.0)
# Requirement already satisfied: pyzmq>=17 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (19.0.1)
# Requirement already satisfied: prometheus-client in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (0.7.1)
# Requirement already satisfied: nbconvert in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (5.6.1)
# Requirement already satisfied: Send2Trash in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (1.5.0)
# Requirement already satisfied: jinja2 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (2.11.2)
# Requirement already satisfied: terminado>=0.8.1 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5->ipyvolume) (2.8.1)
# Requirement already satisfied: parso>=0.7.0 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (0.7.0)
# Requirement already satisfied: wcwidth in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5->ipyvolume) (0.1.9)
# Requirement already satisfied: zipp>=0.5 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5->ipyvolume) (3.1.0)
# Requirement already satisfied: bleach in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (3.1.5)
# Requirement already satisfied: testpath in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (1.4.2)
# Requirement already satisfied: defusedxml in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (1.1.1)
# Requirement already satisfied: packaging in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (20.4)
# Requirement already satisfied: webencodings in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in e:\applications\miniconda3\envs\venv_default\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5->ipyvolume) (2.4.7)
# Installing collected packages: ipywebrtc, traittypes, ipydatawidgets, pythreejs, ipyvolume
# Successfully installed ipydatawidgets-4.2.0 ipyvolume-0.5.2 ipywebrtc-0.6.0 pythreejs-2.3.0 traittypes-0.2.1

# %%
import copy
import numpy
import random
import torch
from torch import nn

# %%
# %run camera.py
# %run rotation.py

# %%
if not torch.cuda.is_available():
    print("OI!  CUDA ISN'T RUNNING FOR SOME REASON!")
    device = "cpu"
else:
    device = "cuda"

# %%
class CameraNet(nn.Module):
    def __init__(self):
        super(CameraNet, self).__init__()
        self.net = nn.Sequential(
            nn.Linear((2+2)*9, 512),  # NINE PAIRS OF x -> x' points!
            nn.LeakyReLU(),
            nn.Linear(512, 512),
            nn.LeakyReLU(),
            nn.Linear(512, 512),
            nn.LeakyReLU(),
            nn.Linear(512, 3+3+5) # 3-translation, 3-rotation, focalx, focaly, prin-x, prin-y, skew.
        )
    
    def forward(self, x):
        # Expect X to be pair-wise x1, y1, x'1, y'1 world -> projection
        # We expect there to be NINE pairs of corresponding points.
        return self.net(x)
    
    def save_layers(self, filename: str):
        input_weight, input_bias = self.net[0].parameters()
        hidden_0_weight, hidden_0_bias = self.net[2].parameters()
        hidden_1_weight, hidden_1_bias = self.net[4].parameters()
        output_weight, output_bias = self.net[6].parameters()
        # Convert all to numpy matrices for storage.
        weights_and_biases = list()
        for mat in [input_weight, input_bias, hidden_0_weight, hidden_0_bias, hidden_1_weight, hidden_1_bias, output_weight, output_bias]:
            weights_and_biases.append(mat.detach().cpu().numpy())
        numpy.savez_compressed(
            filename,
            weights_and_biases
            #input_weight=input_weight,
            #input_bias=input_bias,
            #hidden_0_weight=hidden_0_weight,
            #hidden_0_bias=hidden_0_bias,
            #hidden_1_weight=hidden_1_weight,
            #hidden_1_bias=hidden_1_bias,
            #output_weight=output_weight,
            #output_bias=output_bias
        )
        return weights_and_biases

# %%
model = CameraNet().to(device)
loss_function = nn.MSELoss()  # Makes the most sense for distance errors, imho.
optimizer = torch.optim.SGD(model.parameters(), lr=1e-4)

# %%
lattice = numpy.ones(shape=(9,4))  # This is actually 9x3, but the last is for homogeneous coordinates.
# These are not the points in 2d, these are the positions INSIDE the marker.
for i in range(0, 9):
    x = i%3
    y = i//3
    lattice[i, 0] = x
    lattice[i, 1] = y
    lattice[i, 2] = 0.0  # Z
    lattice[i, 3] = 1.0  # Homogeneous.

def build_example_pair():
    focal_length_x = random.uniform(0.01, 10.0)
    focal_length_y = focal_length_x * random.uniform(0.8, 1.2)
    skew = random.uniform(0, 0.1)
    principal_x, principal_y = random.choice([(1280, 720), (1920, 1080), (640, 480)])
    principal_x /= 2
    principal_y /= 2
    x_translation = random.uniform(-50, 50)
    y_translation = random.uniform(-50, 50)
    z_translation = random.uniform(-50, 50)
    x_rotation = random.uniform(-math.pi/2, math.pi/2)
    y_rotation = random.uniform(-math.pi/2, math.pi/2)
    z_rotation = random.uniform(-math.pi/2, math.pi/2)

    intrinsics = CameraIntrinsics(focal_length_x, focal_length_y, skew, principal_x, principal_y)
    extrinsics = CameraExtrinsics(x_rotation, y_rotation, z_rotation, x_translation, y_translation, z_translation)
    
    transformed = extrinsics.project_points(lattice, intrinsics, renormalize=True)
    
    x = numpy.zeros((36,), dtype=numpy.float32)
    y = numpy.zeros((11,), dtype=numpy.float32)
    
    # Set up projection tuples:
    for idx in range(9):
        # X, Y, X', Y'
        x[idx*4] = lattice[idx, 0]
        x[idx*4 + 1] = lattice[idx, 1]
        x[idx*4 + 2] = transformed[idx, 0]
        x[idx*4 + 3] = transformed[idx, 1]
    
    # Quantize X to integers to add noise.
    x = x.astype(numpy.uint8).astype(numpy.float32)

    # Set up camera predictions:
    y[0] = focal_length_x
    y[1] = focal_length_y
    y[2] = skew
    y[3] = principal_x
    y[4] = principal_y
    y[5] = x_rotation
    y[6] = y_rotation
    y[7] = z_rotation
    y[8] = x_translation
    y[9] = y_translation
    y[10] = z_translation
    
    return x, y

# %%
def train(model, loss_fn, optimizer, num_iterations=100, batch_size=32):
    model.train()
    for i in range(num_iterations):
        #x, y = build_example_pair()
        x_batch = numpy.zeros((batch_size, 36), dtype=numpy.float32)
        y_batch = numpy.zeros((batch_size, 11), dtype=numpy.float32)
        for idx in range(batch_size):
            x, y = build_example_pair()
            x_batch[idx,:] = x[:]
            y_batch[idx,:] = y[:]
        x, y = torch.from_numpy(x_batch).to(device), torch.from_numpy(y_batch).to(device)

        # Compute prediction error
        pred = model(x)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    #print(f"loss: {loss.item():>7f}")
    return loss.item()

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
model = CameraNet().to(device)
loss_function = nn.MSELoss()  # Makes the most sense for distance errors, imho.
optimizer = torch.optim.SGD(model.parameters(), lr=1e-9)

best_loss = 1e10
historical_losses = list()

for t in range(1000):
    loss = train(model, loss_function, optimizer)
    historical_losses.append(loss)
    if loss < best_loss:
        best_loss = loss
        model.save_layers(f"iter_{t}_loss_{int(loss)}")
    if t%100 == 0:
        print(f"{t}: {loss:>3f}")
model.save_layers("final")
# Out:
# 0: 51927.746094
# 100: 32960.132812
# 200: 10716.913086
# 300: 5048.697754
# 400: 3218.262939
# 500: 1707.892456
# 600: 1228.816040
# 700: 590.780090
# 800: 1348.567993
# 900: 836.955811
# [array([[-0.00457262,  0.11078288,  0.03047206, ...,  0.15432335,
#          -0.01277097,  0.09172449],
#         [-0.02465741,  0.08140032, -0.11991473, ..., -0.15844125,
#           0.05823422,  0.0514944 ],
#         [ 0.08703952,  0.11497141,  0.15787224, ...,  0.06516586,
#          -0.0882627 , -0.11792669],
#         ...,
#         [-0.14582965,  0.00396442, -0.09858604, ...,  0.12130584,
#          -0.16073582, -0.08105814],
#         [-0.12470108, -0.0416171 , -0.13449362, ..., -0.09015618,
#          -0.0961545 , -0.16179651],
#         [ 0.13368173, -0.11784005,  0.16386661, ...,  0.01633376,
#          -0.03246503,  0.11596475]], dtype=float32),
#  array([ 0.13286014, -0.00443654,  0.15505134,  0.05655713,  0.06233649,
#          0.10812484, -0.08199704,  0.07525398,  0.09071808,  0.13037367,
#         -0.00155896, -0.10574505,  0.05234814, -0.12441284, -0.08678089,
#         -0.15455662,  0.04596509,  0.16246174, -0.09986725,  0.08356453,
#          0.15762024, -0.06775191, -0.00663131,  0.07244875,  0.06091915,
#         -0.07015183, -0.02931393,  0.05207669, -0.00327523,  0.014277  ,
#          0.07437158, -0.07880237,  0.10165857,  0.06272544, -0.0947459 ,
#          0.10173692, -0.05372246, -0.08532914, -0.11876567,  0.0963525 ,
#         -0.01934408,  0.11242248,  0.14168261,  0.14130403,  0.10662283,
#         -0.0678706 , -0.13278876, -0.11846435,  0.09420805,  0.12517281,
#         -0.06532445, -0.13357326,  0.04985218, -0.03752583,  0.06071495,
